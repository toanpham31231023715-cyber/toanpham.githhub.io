# %%
import requests

url = "https://trading.vietcap.com.vn/api/price/marketStatus/getAll"

headers = {
    "Accept": "application/json",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Cookie": "_ga=GA1.1.184474155.1761625429; device_id=19a290ed51061746; has_tab_key=true; _ga_R0HFZ1HR6R=GS2.1.1762245402.5.0.1762245403.159510s0",
    "Host": "trading.vietcap.com.vn",
    "Pragma": "no-cache",
    "Referer": "https://trading.vietcap.com.vn/ai-news?tab=topTickers&exchange=hose",
    "sec-ch-ua": '"Chromium";v="142", "Google Chrome";v="142", "Not_A Brand";v="99"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/142.0.0.0 Safari/537.36"
}

try:
    response = requests.get(url, headers=headers, timeout=30)
    response.raise_for_status()  # kiểm tra lỗi HTTP
    data = response.json()
    print(data)
except requests.exceptions.RequestException as e:
    print("Lỗi khi gọi API:", e)
# Out:
# {'HSX': {'marketCode': 'HSX', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.701Z', 'sendingTime': '20251110 04:30:00.722', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'UPCOM': {'marketCode': 'UPCOM', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.642Z', 'sendingTime': '20251110 04:30:00.663', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'HNX': {'marketCode': 'HNX', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.397Z', 'sendingTime': '20251110 04:30:00.416', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'BOND': {'marketCode': 'HNX', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.397Z', 'sendingTime': '20251110 04:30:00.416', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'DERIVATIVES': {'marketCode': 'DERIVATIVES', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.463Z', 'sendingTime': '20251110 04:30:00.484', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}}

# %%
r = requests.get(url, headers=headers, timeout=30)

# %%
# kiểm tra
print(r.status_code)  # kiểm tra mã trạng thái (200 là OK)
print(r.text)         # in nội dung trả về dạng chuỗi
# hoặc nếu API trả về JSON:
data = r.json()
print(data)
# Out:
# 200
# {"HSX":{"marketCode":"HSX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.701Z","sendingTime":"20251110 04:30:00.722","messageType":"f","isInPLOEstMatchVolSession":false},"UPCOM":{"marketCode":"UPCOM","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.642Z","sendingTime":"20251110 04:30:00.663","messageType":"f","isInPLOEstMatchVolSession":false},"HNX":{"marketCode":"HNX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.397Z","sendingTime":"20251110 04:30:00.416","messageType":"f","isInPLOEstMatchVolSession":false},"BOND":{"marketCode":"HNX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.397Z","sendingTime":"20251110 04:30:00.416","messageType":"f","isInPLOEstMatchVolSession":false},"DERIVATIVES":{"marketCode":"DERIVATIVES","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.463Z","sendingTime":"20251110 04:30:00.484","messageType":"f","isInPLOEstMatchVolSession":false}}
# {'HSX': {'marketCode': 'HSX', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.701Z', 'sendingTime': '20251110 04:30:00.722', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'UPCOM': {'marketCode': 'UPCOM', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.642Z', 'sendingTime': '20251110 04:30:00.663', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'HNX': {'marketCode': 'HNX', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.397Z', 'sendingTime': '20251110 04:30:00.416', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'BOND': {'marketCode': 'HNX', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.397Z', 'sendingTime': '20251110 04:30:00.416', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}, 'DERIVATIVES': {'marketCode': 'DERIVATIVES', 'status': 'LUNCH_BREAK', 'receivedTime': '2025-11-10T04:30:00.463Z', 'sendingTime': '20251110 04:30:00.484', 'messageType': 'f', 'isInPLOEstMatchVolSession': False}}

# %%
print(r.content)
# Out:
# b'{"HSX":{"marketCode":"HSX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.701Z","sendingTime":"20251110 04:30:00.722","messageType":"f","isInPLOEstMatchVolSession":false},"UPCOM":{"marketCode":"UPCOM","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.642Z","sendingTime":"20251110 04:30:00.663","messageType":"f","isInPLOEstMatchVolSession":false},"HNX":{"marketCode":"HNX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.397Z","sendingTime":"20251110 04:30:00.416","messageType":"f","isInPLOEstMatchVolSession":false},"BOND":{"marketCode":"HNX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.397Z","sendingTime":"20251110 04:30:00.416","messageType":"f","isInPLOEstMatchVolSession":false},"DERIVATIVES":{"marketCode":"DERIVATIVES","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.463Z","sendingTime":"20251110 04:30:00.484","messageType":"f","isInPLOEstMatchVolSession":false}}'

# %%
import pandas as pd
import json

# Dữ liệu byte string bạn cung cấp (từ r.content)
byte_data = b'{"HSX":{"marketCode":"HSX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.701Z","sendingTime":"20251110 04:30:00.722","messageType":"f","isInPLOEstMatchVolSession":false},"UPCOM":{"marketCode":"UPCOM","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.642Z","sendingTime":"20251110 04:30:00.663","messageType":"f","isInPLOEstMatchVolSession":false},"HNX":{"marketCode":"HNX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.397Z","sendingTime":"20251110 04:30:00.416","messageType":"f","isInPLOEstMatchVolSession":false},"BOND":{"marketCode":"HNX","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.397Z","sendingTime":"20251110 04:30:00.416","messageType":"f","isInPLOEstMatchVolSession":false},"DERIVATIVES":{"marketCode":"DERIVATIVES","status":"LUNCH_BREAK","receivedTime":"2025-11-10T04:30:00.463Z","sendingTime":"20251110 04:30:00.484","messageType":"f","isInPLOEstMatchVolSession":false}}'

# --- BẮT ĐẦU CODE CHUYỂN ĐỔI ---

# Bước 1: Giải mã (decode) byte string thành một string UTF-8
json_string = byte_data.decode('utf-8')

# Bước 2: Phân tích (parse) string JSON thành một dictionary của Python
data_dict = json.loads(json_string)

# Bước 3: Chuyển dictionary thành DataFrame
# Chúng ta dùng orient='index' để nói với pandas rằng
# các keys của dictionary (ví dụ: 'HSX', 'UPCOM') nên được dùng làm CHỈ MỤC (hàng)
df = pd.DataFrame.from_dict(data_dict, orient='index')

# In DataFrame ra xem kết quả
print(df)
# Out:
#               marketCode       status              receivedTime  \
# HSX                  HSX  LUNCH_BREAK  2025-11-10T04:30:00.701Z
# UPCOM              UPCOM  LUNCH_BREAK  2025-11-10T04:30:00.642Z
# HNX                  HNX  LUNCH_BREAK  2025-11-10T04:30:00.397Z
# BOND                 HNX  LUNCH_BREAK  2025-11-10T04:30:00.397Z
# DERIVATIVES  DERIVATIVES  LUNCH_BREAK  2025-11-10T04:30:00.463Z
#
#                        sendingTime messageType  isInPLOEstMatchVolSession
# HSX          20251110 04:30:00.722           f                      False
# UPCOM        20251110 04:30:00.663           f                      False
# HNX          20251110 04:30:00.416           f                      False
# BOND         20251110 04:30:00.416           f                      False
# DERIVATIVES  20251110 04:30:00.484           f                      False

# %%
df.head()
# Out:
#               marketCode       status              receivedTime  \
# HSX                  HSX  LUNCH_BREAK  2025-11-10T04:30:00.701Z
# UPCOM              UPCOM  LUNCH_BREAK  2025-11-10T04:30:00.642Z
# HNX                  HNX  LUNCH_BREAK  2025-11-10T04:30:00.397Z
# BOND                 HNX  LUNCH_BREAK  2025-11-10T04:30:00.397Z
# DERIVATIVES  DERIVATIVES  LUNCH_BREAK  2025-11-10T04:30:00.463Z
#
#                        sendingTime messageType  isInPLOEstMatchVolSession
# HSX          20251110 04:30:00.722           f                      False
# UPCOM        20251110 04:30:00.663           f                      False
# HNX          20251110 04:30:00.416           f                      False
# BOND         20251110 04:30:00.416           f                      False
# DERIVATIVES  20251110 04:30:00.484           f                      False

# %%
# thư viện vnstock
# !pip install git+https://github.com/thinh-vu/vnstock.git@main
# Out:
# Collecting git+https://github.com/thinh-vu/vnstock.git@main
#   Cloning https://github.com/thinh-vu/vnstock.git (to revision main) to /tmp/pip-req-build-6degogu7
#   Running command git clone --filter=blob:none --quiet https://github.com/thinh-vu/vnstock.git /tmp/pip-req-build-6degogu7
#   Resolved https://github.com/thinh-vu/vnstock.git to commit 7bc8ec5eeda5c107995975d985306405ccbc512e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (4.13.4)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (2.3.1)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (0.13.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock==3.2.7) (3.1.5)
# Requirement already satisfied: pydantic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock==3.2.7) (2.12.4)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (7.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (25.0)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock==3.2.7) (8.7.0)
# Requirement already satisfied: tenacity in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock==3.2.7) (9.1.2)
# Requirement already satisfied: vnai>=2.2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock==3.2.7) (2.2.3)
# Collecting vnstock_ezchart>=0.0.3 (from vnstock==3.2.7)
#   Using cached vnstock_ezchart-0.0.3-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata>=1.0->vnstock==3.2.7) (3.23.0)
# Requirement already satisfied: cffi>=1.17.1 in /home/codespace/.local/lib/python3.12/site-packages (from vnai>=2.2.2->vnstock==3.2.7) (1.17.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.17.1->vnai>=2.2.2->vnstock==3.2.7) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (2025.7.9)
# Requirement already satisfied: squarify in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart>=0.0.3->vnstock==3.2.7) (0.4.4)
# Requirement already satisfied: wordcloud in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart>=0.0.3->vnstock==3.2.7) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock==3.2.7) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock==3.2.7) (4.14.1)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openpyxl->vnstock==3.2.7) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->vnstock==3.2.7) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock==3.2.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock==3.2.7) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock==3.2.7) (0.4.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn->vnstock==3.2.7) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (3.2.3)
# Downloading vnstock_ezchart-0.0.3-py3-none-any.whl (15 kB)
# Building wheels for collected packages: vnstock
#   Building wheel for vnstock (pyproject.toml) ... done
#   Created wheel for vnstock: filename=vnstock-3.2.7-py3-none-any.whl size=210776 sha256=9585d1a69252a52973941a203e33f991e65edcf7303397d59f0d172a0149f3c6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_hbmexk3/wheels/bf/e3/28/3d02eb0adfc4664c0a84b3900fc986b516df7015f08a33000b
# Successfully built vnstock
# Installing collected packages: vnstock_ezchart, vnstock
#   Attempting uninstall: vnstock_ezchart
#     Found existing installation: vnstock_ezchart 0.0.2
#     Uninstalling vnstock_ezchart-0.0.2:
#       Successfully uninstalled vnstock_ezchart-0.0.2
#   Attempting uninstall: vnstock
#     Found existing installation: vnstock 3.2.6
#     Uninstalling vnstock-3.2.6:
#       Successfully uninstalled vnstock-3.2.6
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [vnstock]m1/2 [vnstock]
# Successfully installed vnstock-3.2.7 vnstock_ezchart-0.0.3
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install vnstock
# Out:
# Requirement already satisfied: vnstock in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.2.7)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from vnstock) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock) (4.13.4)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from vnstock) (2.3.1)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (from vnstock) (0.13.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock) (3.1.5)
# Requirement already satisfied: pydantic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock) (2.12.4)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.12/site-packages (from vnstock) (7.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock) (25.0)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock) (8.7.0)
# Requirement already satisfied: tenacity in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock) (9.1.2)
# Requirement already satisfied: vnai>=2.2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock) (2.2.3)
# Requirement already satisfied: vnstock_ezchart>=0.0.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock) (0.0.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata>=1.0->vnstock) (3.23.0)
# Requirement already satisfied: cffi>=1.17.1 in /home/codespace/.local/lib/python3.12/site-packages (from vnai>=2.2.2->vnstock) (1.17.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.17.1->vnai>=2.2.2->vnstock) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock) (2025.7.9)
# Requirement already satisfied: squarify in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart>=0.0.3->vnstock) (0.4.4)
# Requirement already satisfied: wordcloud in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart>=0.0.3->vnstock) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock) (4.14.1)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openpyxl->vnstock) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->vnstock) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock) (0.4.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn->vnstock) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock) (3.2.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install vnstock3 --upgrade
# Out:
# Collecting vnstock3
#   Downloading vnstock3-3.2.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from vnstock3) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock3) (4.13.4)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from vnstock3) (2.3.1)
# Requirement already satisfied: vnai>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock3) (2.2.3)
# Requirement already satisfied: openpyxl in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock3) (3.1.5)
# Requirement already satisfied: pydantic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock3) (2.12.4)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.12/site-packages (from vnstock3) (7.0.0)
# Requirement already satisfied: fake_useragent in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock3) (2.2.0)
# Requirement already satisfied: vnstock_ezchart in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock3) (0.0.3)
# Requirement already satisfied: click in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock3) (8.3.0)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (from vnstock3) (0.13.2)
# Requirement already satisfied: cffi>=1.17.1 in /home/codespace/.local/lib/python3.12/site-packages (from vnai>=2.0->vnstock3) (1.17.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.17.1->vnai>=2.0->vnstock3) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock3) (2025.7.9)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock3) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock3) (4.14.1)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openpyxl->vnstock3) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock3) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock3) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->vnstock3) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock3) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic->vnstock3) (0.4.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn->vnstock3) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (25.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock3) (3.2.3)
# Requirement already satisfied: squarify in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart->vnstock3) (0.4.4)
# Requirement already satisfied: wordcloud in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart->vnstock3) (1.9.4)
# Requirement already satisfied: vnstock>=3.2.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock_ezchart->vnstock3) (3.2.7)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock>=3.2.7->vnstock_ezchart->vnstock3) (8.7.0)
# Requirement already satisfied: tenacity in /usr/local/python/3.12.1/lib/python3.12/site-packages (from vnstock>=3.2.7->vnstock_ezchart->vnstock3) (9.1.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata>=1.0->vnstock>=3.2.7->vnstock_ezchart->vnstock3) (3.23.0)
# Downloading vnstock3-3.2.1-py3-none-any.whl (121 kB)
# Installing collected packages: vnstock3
# Successfully installed vnstock3-3.2.1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# import toàn bộ ừ vnstock
from vnstock import *
# Out:
# Non-200 response fetching content: 502
# ## 👋 Chào mừng bạn đến với Vnstock!
# Cảm ơn bạn đã sử dụng package phân tích chứng khoán #1 tại Việt Nam
# * Tài liệu: [Sổ tay hướng dẫn](https://vnstocks.com/docs)
# * Cộng đồng: [Nhóm Facebook](https://facebook.com/groups/vnstock.official)
# Khám phá các tính năng mới nhất và tham gia cộng đồng để nhận hỗ trợ.

# %%
from vnstock import Listing
listing = Listing()
listing.all_symbols()
# Out:
# Non-200 response fetching content: 502
# ## 👋 Chào mừng bạn đến với Vnstock!
# Cảm ơn bạn đã sử dụng package phân tích chứng khoán #1 tại Việt Nam
# * Tài liệu: [Sổ tay hướng dẫn](https://vnstocks.com/docs)
# * Cộng đồng: [Nhóm Facebook](https://facebook.com/groups/vnstock.official)
# Khám phá các tính năng mới nhất và tham gia cộng đồng để nhận hỗ trợ.
#      symbol                                         organ_name
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# ...     ...                                                ...
# 1722    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# 1723    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1724    AAH                           Công ty Cổ phần Hợp Nhất
# 1725    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1726    A32                                 Công ty Cổ phần 32
#
# [1727 rows x 2 columns]

# %%
# dữ liệu giá lịch sử
from vnstock import Vnstock
acb = Vnstock().stock(symbol='ACB', source='VCI')
hpg = Vnstock().stock(symbol='HPG', source='VCI')
nkg = Vnstock().stock(symbol='NKG', source='VCI')
hsg = Vnstock().stock(symbol='HSG', source='VCI')
pom = Vnstock().stock(symbol='POM', source='VCI')
tvn = Vnstock().stock(symbol='TVN', source='VCI')
acb.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
hpg.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
nkg.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
hsg.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
pom.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
tvn.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
# Out:
#           time   open   high    low  close   volume
# 0   2021-10-28  18.24  18.81  17.86  18.62  2758996
# 1   2021-10-29  18.62  18.81  18.24  18.43  2193099
# 2   2021-11-01  18.52  18.62  17.95  18.24  2057915
# 3   2021-11-02  18.24  18.52  17.86  18.24  1765832
# 4   2021-11-03  18.24  18.43  17.67  17.86  1890574
# ..         ...    ...    ...    ...    ...      ...
# 980 2025-10-03   8.10   8.10   7.90   8.00   790400
# 981 2025-10-06   8.00   8.40   8.00   8.30   272200
# 982 2025-10-07   8.30   8.30   8.00   8.10   212800
# 983 2025-10-08   8.20   8.30   8.10   8.20   246100
# 984 2025-10-09   8.20   8.20   8.10   8.20   228500
#
# [985 rows x 6 columns]

# %%
hpg = Vnstock().stock(symbol='HPG', source='VCI')
hpg.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
# Out:
#           time   open   high    low  close    volume
# 0   2021-10-28  33.20  33.37  32.85  33.25  21923800
# 1   2021-10-29  33.25  33.31  32.74  32.74  23878000
# 2   2021-11-01  32.74  32.74  31.93  31.93  45218500
# 3   2021-11-02  31.82  32.34  31.65  31.82  25669500
# 4   2021-11-03  32.22  32.28  31.70  31.88  29867100
# ..         ...    ...    ...    ...    ...       ...
# 980 2025-10-03  28.10  28.10  27.35  27.65  58123500
# 981 2025-10-06  28.10  29.20  28.10  29.20  71269500
# 982 2025-10-07  29.20  29.35  29.00  29.00  41398600
# 983 2025-10-08  29.25  29.40  28.75  29.20  59953000
# 984 2025-10-09  29.40  29.40  28.85  28.95  42551700
#
# [985 rows x 6 columns]

# %%
nkg = Vnstock().stock(symbol='NKG', source='VCI')
nkg.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
# Out:
#           time   open   high    low  close    volume
# 0   2021-10-28  34.46  35.40  34.15  34.84   6005100
# 1   2021-10-29  34.46  34.78  33.52  34.09  19314300
# 2   2021-11-01  33.84  33.96  33.02  33.40  13646000
# 3   2021-11-02  33.09  34.28  32.96  33.21  10912800
# 4   2021-11-03  33.21  33.59  31.64  31.64  18305400
# ..         ...    ...    ...    ...    ...       ...
# 980 2025-10-03  17.05  17.10  16.60  16.70  12484100
# 981 2025-10-06  16.90  17.80  16.85  17.65   7403200
# 982 2025-10-07  17.80  17.80  17.30  17.30   7089200
# 983 2025-10-08  17.60  17.75  17.20  17.70  10543900
# 984 2025-10-09  17.90  18.00  17.60  17.75   7860900
#
# [985 rows x 6 columns]

# %%
hsg = Vnstock().stock(symbol='HSG', source='VCI')
hsg.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
# Out:
#           time   open   high    low  close    volume
# 0   2021-10-28  37.23  37.23  36.57  36.77   6865500
# 1   2021-10-29  37.00  37.07  35.88  36.31  11471500
# 2   2021-11-01  36.38  36.46  35.12  35.23  17399100
# 3   2021-11-02  35.23  35.96  34.97  35.08  11151200
# 4   2021-11-03  35.23  35.39  34.08  34.43  15160400
# ..         ...    ...    ...    ...    ...       ...
# 980 2025-10-03  18.60  18.60  18.05  18.05   5984600
# 981 2025-10-06  18.30  19.00  18.15  18.80   4100400
# 982 2025-10-07  18.95  18.95  18.50  18.50   2598400
# 983 2025-10-08  18.90  18.95  18.50  18.80   3554400
# 984 2025-10-09  18.95  19.10  18.70  18.85   2626900
#
# [985 rows x 6 columns]

# %%
pom = Vnstock().stock(symbol='POM', source='VCI')
pom.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
# Out:
#           time  open  high   low  close   volume
# 0   2020-10-29  4.85   5.5  4.85   5.25    29050
# 1   2020-10-30  5.25   5.5  5.16   5.35     1820
# 2   2020-11-02  5.35   5.5  5.35   5.40    50000
# 3   2020-11-03  5.40   5.5  5.30   5.40    26640
# 4   2020-11-04  5.06   5.5  5.06   5.40    21290
# ..         ...   ...   ...   ...    ...      ...
# 980 2025-09-05  2.00   2.3  2.00   2.30  1651400
# 981 2025-09-12  2.10   2.4  2.10   2.30   574700
# 982 2025-09-19  2.20   2.3  1.90   2.00  2273100
# 983 2025-09-26  2.00   2.0  1.80   1.90  1237600
# 984 2025-10-03  1.80   1.9  1.70   1.70   732200
#
# [985 rows x 6 columns]

# %%
tvn = Vnstock().stock(symbol='TVN', source='VCI')
tvn.quote.history(start='2022-01-01', end='2025-10-8', interval='1D')
