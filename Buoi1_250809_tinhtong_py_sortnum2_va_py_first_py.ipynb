# %% [markdown]
# <a href="https://colab.research.google.com/github/toanpham31231023715-cyber/toanpham.githhub.io/blob/main/Buoi1_250809_tinhtong_py_sortnum2_va_py_first_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tinhtong.py
a = 10
b = 10
print(f'{a}+{b}={a+b}')
print("-"*10)
# Out:
# 10+10=20
# ----------

# %%
#sortnum2_va.py
num1 = float(input("Num 1: "))
num2 = float(input("Num 2: "))

if num1 < num2:
    final1 = num1
    final2 = num2
else:
    final1 = num2
    final2 = num1

print(final1, final2)
# Out:
# Num 1: 2
# Num 2: 5
# 2.0 5.0

# %%
#first.py
a=27
b=6
c = a % b;
print(f"The value of c is {c}.");
# Out:
# The value of c is 3.
