# %% [markdown]
# <a href="https://colab.research.google.com/github/toanpham31231023715-cyber/toanpham.githhub.io/blob/main/Baitapthuchanh01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bài tập mẫu**

# %% [markdown]
# Bài 1: In chuỗi

# %%
print("Whoever is happy will make others happy too")
print("--Anne Frank")
# Out:
# Whoever is happy will make others happy too
# --Anne Frank

# %% [markdown]
# Bài 2: Biểu thức tính toán

# %%
# Nhap du lieu
a = int(input("Nhap so a: "))
b = int(input("Nhap so b: "))

# Phep tinh
Cong = a + b
Tru = a - b
Nhan = a * b
Chia_Nguyen = a // b
Du= a % b
Chia_Thuc = a / b

# In ket qua
print("Cac ket qua tinh toan: ")
print("%-5d + %5d = %5d"%(a, b, Cong))
print("%-5d - %5d = %5d"%(a, b, Tru))
print("%-5d * %5d = %5d"%(a, b, Nhan))
print("%-5d / %5d = %5d"%(a, b, Chia_Nguyen))
print("%-5d / %5d = %5d"%(a, b, Du))
print("%-5d / %5d = %5.2f"%(a, b, Chia_Thuc))
# Out:
# Nhap so a: 3
# Nhap so b: 5
# Cac ket qua tinh toan:
# 3     +     5 =     8
# 3     -     5 =    -2
# 3     *     5 =    15
# 3     /     5 =     0
# 3     /     5 =     3
# 3     /     5 =  0.60

# %% [markdown]
# Bài 3: Biểu thức so sánh

# %%
# Nhap du lieu
a = float(input("Nhap so a: "))
b = float(input("Nhap so b: "))

# Phep tinh
NhoHon = (a < b)
NhoHonBang = (a <= b)
LonHon = (a > b)
LonHonBang = (a >= b)
Bang = (a == b)
KhacNhau = (a != b)
# In ket qua
print("Ket qua so sanh hai so thuc %.2f va %.2f:" % (a, b))
print("%-8.2f < %8.2f: %8s" % (a, b, NhoHon))
print("%-8.2f <= %8.2f: %8s" % (a, b, NhoHonBang))
print("%-8.2f > %8.2f: %8s" % (a, b, LonHon))
print("%-8.2f >= %8.2f: %8s" % (a, b, LonHonBang))
print("%-8.2f == %8.2f: %8s" % (a, b, Bang))
print("%-8.2f != %8.2f: %8s" % (a, b, KhacNhau))
# Out:
# Nhap so a: 4
# Nhap so b: 6
# Ket qua so sanh hai so thuc 4.00 va 6.00:
# 4.00     <     6.00:     True
# 4.00     <=     6.00:     True
# 4.00     >     6.00:    False
# 4.00     >=     6.00:    False
# 4.00     ==     6.00:    False
# 4.00     !=     6.00:     True

# %% [markdown]
# Bài 4: Tính giá trị hàm số

# %%
# Thu vien
import math

# Nhap du lieu
x = float(input("Nhap vao gia tri cua bien so x: "))

# Phep tinh
fx = x + math.pow(x, 5) / (1 * 2 * 3 * 4 * 5) + \
math.sqrt(abs(x)) / math.pow(x, 3.0 / 2)

# In ket qua
print("Gia tri cua ham so f(%.2f) = %.2f."%(x, fx))
# Out:
# Nhap vao gia tri cua bien so x: 3
# Gia tri cua ham so f(3.00) = 5.36.

# %% [markdown]
# Bài 5: Tổng chữ số

# %%
# Nhap du lieu
n = int(input("Nhap so nguyen 4 chu so: "))

# Kiem tra dieu kien va xuat ket qua
if 1000 <= abs(n) <= 9999:
    tong = 0
    for i in str(abs(n)):
        tong += int(i)
    print("Tong cac chu so cua", n, "la", tong)
else:
    print("Vui long nhap so nguyen co 4 chu so")
# Out:
# Nhap so nguyen 4 chu so: 2343
# Tong cac chu so cua 2343 la 12

# %% [markdown]
# **Bài tập thực hành**

# %% [markdown]
# Bài 1: In nhãn

# %%
print("**************************")
print("* Truong: Dai Hoc UEH    *")
print("* Khoa: Kinh Te          *")
print("* Ho ten: PhamHuuAnhToan *")
print("**************************")
# Out:
# **************************
# * Truong: Dai Hoc UEH    *
# * Khoa: Kinh Te          *
# * Ho ten: PhamHuuAnhToan *
# **************************

# %% [markdown]
# Bài 2: Tính diện tích và chu vi hình tròn

# %%
# Nhap du lieu
r = int(input("Nhap ban kinh R: "))

# Gan bien
pi = 3.14

# In ra ket qua
print("Dien tich S = ", pi * r ** 2)
print("Chu_vi P = ", round(2 * pi * r, 1))
# Out:
# Nhap ban kinh R: 4
# Dien tich S =  50.24
# Chu_vi P =  25.1

# %% [markdown]
# Bài 3: Đổi sang giây

# %%
# Nhap du lieu
h = int(input("Nhap so gio: "))
s = int(input("Nhap so giay: "))
m = int(input("Nhap so phut: "))

# Chuyen doi
hours_giay = h * 3600
minute_giay = m * 60
tong_so_giay = hours_giay + minute_giay + s

# In ra ket qua
print("Tong so giay cua " + str(h) + ":" + str(m) + ":" + str(s) + " la " + str(tong_so_giay) + " giay")
# Out:
# Nhap so gio: 6
# Nhap so giay: 25
# Nhap so phut: 1
# Tong so giay cua 6:1:25 la 21685 giay

# %% [markdown]
# Bài 4: Đổi sang giờ phút giây

# %%
# Nhap du lieu
so_giay = int(input("Nhap vao tong so giay "))

#Phep tinh
h = so_giay // 3600
m = (so_giay % 3600) // 60
s = (so_giay % 3600) % 60

print(str(so_giay) + " giay co dang " + str(h) + ":" + str(m) + ":" + str(s))
# Out:
# Nhap vao tong so giay 2353465
# 2353465 giay co dang 653:44:25

# %% [markdown]
# Bài 5: Tính diện tích tam giác

# %%
# Nhap du lieu
a = float(input("Nhap do dai canh a: "))
b = float(input("Nhap do dai canh b: "))
c = float(input("Nhap do dai canh c: "))

#Phep tinh
p = (a + b +c) / 2
S = (p * (p - a) * (p - b) * (p - c)) ** 0.5

#In ket qua
print("Dien tich tam giac S =", round(S, 2))
# Out:
# Nhap do dai canh a: 2
# Nhap do dai canh b: 3
# Nhap do dai canh c: 4
# Dien tich tam giac S = 2.9

# %% [markdown]
# Bài 6: Hàm mũ

# %%
# Nhap du lieu
a = float(input("Nhap so thuc a: "))
n = int(input("Nhap so mu n: "))

# In ket qua
print("Ket qua a^n =", round(a ** n))
# Out:
# Nhap so thuc a: 3
# Nhap so mu n: 6
# Ket qua a^n = 729

# %% [markdown]
# Bài 7: Đảo số

# %%
# Nhap du lieu
x = int(input("x = "))
y = int(str(x)[::-1])

# In ket qua
print("Thu tu thay doi cua x", x, "la", y)
# Out:
# x = 4
# Thu tu thay doi cua x 4 la 4

# %% [markdown]
# Bài 8: Độ sang radion

# %%
# Nhap du lieu
degree = float(input("Nhap goc (do): "))

# Gan bien
pi = 3.141592653589793
radian = degree * (pi / 180)

# In ket qua
print("Goc", degree, "do =", round(radian, 2), "radian")
# Out:
# Nhap goc (do): 32
# Goc 32.0 do = 0.56 radian

# %% [markdown]
# Bài 9: Hàm số 1

# %%
# Thu vien
import math

# Nhap du lieu
x = float(input("x = "))

# Dieu kien va phep tinh
if x < 0:
    print("x phai >= 0 de y1, y2 co gia tri thuc")
else:
  y1 = 4 * (x**2 + 10*x*math.sqrt(x) + 3*x + 1)
  y2 = (math.sin(math.pi * x**2) + math.sqrt(x**2 + 1)) / (math.exp(2*x) + math.cos((math.pi/4)*x))

  # In ket qua
  print("y1 =", round(y1, 2))
  print("y2 =", round(y2, 2))
# Out:
# x = 32
# y1 = 11724.77
# y2 = 0.0

# %% [markdown]
# Bài 10: Khoảng cách

# %%
# Dua thu vien
import math

# Nhap du lieu
x1 = float(input("Nhap x1: "))
y1 = float(input("Nhap y1: "))
x2 = float(input("Nhap x2: "))
y2 = float(input("Nhap y2: "))

# Phep tinh
d = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# In du lieu
print("Khoang cach cua AB =", round(d, 2))
# Out:
# Nhap x1: 3
# Nhap y1: 6
# Nhap x2: 2
# Nhap y2: 6
# Khoang cach cua AB = 1.0

# %% [markdown]
# **KẾT THÚC**
