# %% [markdown]
# <a href="https://colab.research.google.com/github/toanpham31231023715-cyber/toanpham.githhub.io/blob/main/buoi02_250816_bai02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile SoSanh.in1
# 5
# 6
# Out:
# Overwriting SoSanh.in1

# %%
# !python SoSanh.py < SoSanh.in1
# Out:
# Moi ban nhap so a: Moi ban nhap so b: Ket qua so sanh hai so thuc 5.00 va 6.00:
# 5.00     <     6.00:     True
# 5.00     <=     6.00:     True
# 5.00     >     6.00:    False
# 5.00     >=     6.00:    False
# 5.00     ==     6.00:    False
# 5.00     !=     6.00:     True

# %%
# %%writefile Max3Num.in1
# 2
# 5
# 4
# Out:
# Overwriting Max3Num.in1

# %%
import random, os
input_dir = 'Max3Num/input'
output_dir = 'Max3Num/output'
# !rm -r $input_dir
# !rm -r $output_dir
os.makedirs(input_dir, exist_ok = True)
os.makedirs(output_dir, exist_ok = True)
for ti in range(1, 11):
    a = random.randint(1, 100000)
    b = random.randint(1, 100000)
    c = random.randint(1, 100000)
    with open('Max3Num.txt', 'w') as file:
        file.write(str(a) + '\n')
        file.write(str(b) + '\n')
        file.write(str(c) + '\n')
    # !python Max3Num.py <Max3Num.txt >Max3Num.out
    # !cat Max3Num.txt
    # !cat Max3Num.out
    input_path = f'{input_dir}/input{ti:02d}.txt'
    output_path = f'{output_dir}/output{ti:02d}.txt'
    print(input_path)
    print(output_path)
    # !cp Max3Num.txt $input_path
    # !cp Max3Num.out $output_path
    print("-"*50)
    pass
# Out:
# rm: cannot remove 'Max3Num/input': No such file or directory
# rm: cannot remove 'Max3Num/output': No such file or directory
# 66243
# 12818
# 4238
# Max(66243, 12818, 4238) = 66243
# Max3Num/input/input01.txt
# Max3Num/output/output01.txt
# --------------------------------------------------
# 34183
# 86583
# 10372
# Max(34183, 86583, 10372) = 86583
# Max3Num/input/input02.txt
# Max3Num/output/output02.txt
# --------------------------------------------------
# 67896
# 15991
# 37433
# Max(67896, 15991, 37433) = 67896
# Max3Num/input/input03.txt
# Max3Num/output/output03.txt
# --------------------------------------------------
# 98900
# 24268
# 56499
# Max(98900, 24268, 56499) = 98900
# Max3Num/input/input04.txt
# Max3Num/output/output04.txt
# --------------------------------------------------
# 19051
# 78708
# 20624
# Max(19051, 78708, 20624) = 78708
# Max3Num/input/input05.txt
# Max3Num/output/output05.txt
# --------------------------------------------------
# 620
# 59164
# 63142
# Max(620, 59164, 63142) = 63142
# Max3Num/input/input06.txt
# Max3Num/output/output06.txt
# --------------------------------------------------
# 15567
# 16632
# 3160
# Max(15567, 16632, 3160) = 16632
# Max3Num/input/input07.txt
# Max3Num/output/output07.txt
# --------------------------------------------------
# 86639
# 68066
# 82189
# Max(86639, 68066, 82189) = 86639
# Max3Num/input/input08.txt
# Max3Num/output/output08.txt
# --------------------------------------------------
# 27957
# 86552
# 17362
# Max(27957, 86552, 17362) = 86552
# Max3Num/input/input09.txt
# Max3Num/output/output09.txt
# --------------------------------------------------
# 69995
# 35306
# 43479
# Max(69995, 35306, 43479) = 69995
# Max3Num/input/input10.txt
# Max3Num/output/output10.txt
# --------------------------------------------------

# %%
import shutil

# %%
# !python Max3Num.py <Max3Num.in1
# Out:
# Max(2, 5, 4) = 5
